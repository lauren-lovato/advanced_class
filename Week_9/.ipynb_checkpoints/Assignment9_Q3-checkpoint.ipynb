# %% [markdown]
# ## Week 9, Assignment 9, Question 3

# %% [markdown]
# ### UNHCR Immigration Statistics API

# %%
import requests
import pandas as pd

# %% [markdown]
# ### UNHCR Asylum seekers for France from January 2015

# %%
url = 'http://popdata.unhcr.org/api/stats/asylum_seekers_monthly.json?year=2015&month=1&coa=FRA'
data = requests.get(url)
as_json = data.json()
df = pd.DataFrame(as_json)

# %%
df.sort_values(by='value', ascending = False)
# Out:
#    country_of_asylum country_of_asylum_en country_of_origin  \
# 82               FRA               France               SRB
# 13               FRA               France               COD
# 42               FRA               France               RUS
# 8                FRA               France               CHN
# 56               FRA               France               HTI
# 25               FRA               France               ALB
# 52               FRA               France               SYR
# 15               FRA               France               BGD
# 47               FRA               France               GIN
# 12               FRA               France               LKA
# 26               FRA               France               DZA
# 74               FRA               France               UKR
# 75               FRA               France               PAK
# 1                FRA               France               ARM
# 51               FRA               France               SDN
# ...

# %% [markdown]
# ### France recieved the most immigrants in January 2015 from Serbia and Kosovo.

# %% [markdown]
# ### What were the 5 countries that contributed the most immigrants in January of 2015? Serbia and Kosovo, Democratic Republic of Congo, Russia, China, Haiti

# %%
df_1 = df.loc[df['value'] == 1]
pd.set_option('display.max_rows', 100)
df_1
# Out:
#    country_of_asylum country_of_asylum_en country_of_origin  \
# 0                FRA               France               EGY
# 1                FRA               France               ARM
# 2                FRA               France               AZE
# 3                FRA               France               BDI
# 4                FRA               France               BEN
# 5                FRA               France               ERI
# 6                FRA               France               ETH
# 7                FRA               France               GMB
# 8                FRA               France               CHN
# 9                FRA               France               CMR
# 10               FRA               France               COG
# 11               FRA               France               AFG
# 12               FRA               France               LKA
# 13               FRA               France               COD
# 14               FRA               France               IRN
# ...

# %% [markdown]
# ### From what countries did only 1 immigrant arrive from France in January of 2015? see list above - there are 83

# %% [markdown]
# ### UNHCR Asylum seekers for France from January 2018

# %%
url = 'http://popdata.unhcr.org/api/stats/asylum_seekers_monthly.json?year=2018&month=1&coa=FRA'
data = requests.get(url)
as_json = data.json()
df2 = pd.DataFrame(as_json)

# %%
df2.sort_values(by='value', ascending = False)
# Out:
#    country_of_asylum country_of_asylum_en country_of_origin  \
# 16               FRA               France               AFG
# 27               FRA               France               ALB
# 40               FRA               France               GEO
# 48               FRA               France               GIN
# 62               FRA               France               CIV
# 20               FRA               France               BGD
# 29               FRA               France               DZA
# 18               FRA               France               COD
# 79               FRA               France               SRB
# 53               FRA               France               SDN
# 56               FRA               France               HTI
# 1                FRA               France               ARM
# 54               FRA               France               SYR
# 73               FRA               France               NGA
# 45               FRA               France               RUS
# ...

# %% [markdown]
# ### From what country did France recieve the most immigrants in January 2018? Afghanistan

# %% [markdown]
# ### What were the 5 countries that contributed the most immigrants in January of 2018? Afghanistan, Albania, Georgia, Guinea and Cote d'Ivoire

# %%
df_2 = df2.loc[df2['value'] == 1]
pd.set_option('display.max_rows', 100)
df_2
# Out:
# Empty DataFrame
# Columns: [country_of_asylum, country_of_asylum_en, country_of_origin, country_of_origin_en, month, month_en, value, year]
# Index: []

# %%
df2.sort_values(by='value', ascending = True)
# Out:
#    country_of_asylum country_of_asylum_en country_of_origin  \
# 39               FRA               France               PER
# 64               FRA               France               SLE
# 15               FRA               France               BEN
# 50               FRA               France               KGZ
# 68               FRA               France               NER
# 47               FRA               France               MDA
# 28               FRA               France               BLR
# 72               FRA               France               VNM
# 58               FRA               France               LCA
# 6                FRA               France               GNQ
# 42               FRA               France               GHA
# 3                FRA               France               BHR
# 76               FRA               France               SSD
# 41               FRA               France               KHM
# 21               FRA               France               MDG
# ...

# %% [markdown]
# ### From what countries did only 1 immigrant arrive from France in January of 2018? There were none. The lowest value is 5.
