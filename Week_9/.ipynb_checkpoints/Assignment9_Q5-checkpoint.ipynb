# %% [markdown]
# ## Week 9, Assignment 9, Question 5

# %%
import arcgis
from arcgis.features import SpatialDataFrame 
import pandas as pd

# %%
xcl = "fsi-2018.xlsx"
data_xls = pd.read_excel(xcl, index_col=None)
data_xls.to_csv("fsi-2018.csv")

# %%
fsi_csv = pd.read_csv("fsi-2018.csv")
fsi_csv.head()
# Out:
#    Unnamed: 0                   Country        Year Rank       Total  \
# 0           0               South Sudan  2018-01-01  1st  113.357315
# 1           1                   Somalia  2018-01-01  2nd  113.200796
# 2           2                     Yemen  2018-01-01  3rd  112.671504
# 3           3                     Syria  2018-01-01  4th  111.393031
# 4           4  Central African Republic  2018-01-01  5th  111.126345
#
#    C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                    10.0                       9.7                  9.7
# 1                     9.7                      10.0                  9.0
# 2                     9.9                      10.0                  9.5
# 3                     9.9                       9.9                  9.9
# 4                     9.1                       9.7                  8.8
#
#    E1: Economy  E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# ...

# %%
df = pd.DataFrame(fsi_csv)

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'Country', 'Year', 'Rank', 'Total',
#        'C1: Security Apparatus', 'C2: Factionalized Elites',
#        'C3: Group Grievance', 'E1: Economy', 'E2: Economic Inequality',
#        'E3: Human Flight and Brain Drain', 'P1: State Legitimacy',
#        'P2: Public Services', 'P3: Human Rights',
#        'S1: Demographic Pressures', 'S2: Refugees and IDPs',
#        'X1: External Intervention'], dtype=object)

# %%
C1 = df.sort_values(by='C1: Security Apparatus', ascending = False)
C1.head(10)
# Out:
#     Unnamed: 0                   Country        Year  Rank       Total  \
# 0            0               South Sudan  2018-01-01   1st  113.357315
# 8            8               Afghanistan  2018-01-01   9th  106.620768
# 2            2                     Yemen  2018-01-01   3rd  112.671504
# 3            3                     Syria  2018-01-01   4th  111.393031
# 46          46               Philippines  2018-01-01  47th   85.499882
# 1            1                   Somalia  2018-01-01   2nd  113.200796
# 7            7                      Chad  2018-01-01   8th  108.311870
# 26          26                      Mali  2018-01-01  27th   93.581321
# 24          24                     Libya  2018-01-01  25th   94.600000
# 4            4  Central African Republic  2018-01-01   5th  111.126345
#
#     C1: Security Apparatus  C2: Factionalized Elites  C3: Group Grievance  \
# 0                     10.0                       9.7                  9.7
# ...

# %%
C1_df = C1.drop(columns= ['Unnamed: 0', 'Year', 'Rank', 'Total',
       'C2: Factionalized Elites',
       'C3: Group Grievance', 'E1: Economy', 'E2: Economic Inequality',
       'E3: Human Flight and Brain Drain', 'P1: State Legitimacy',
       'P2: Public Services', 'P3: Human Rights',
       'S1: Demographic Pressures', 'S2: Refugees and IDPs',
       'X1: External Intervention'])
C1_df.head(10)
# Out:
#                      Country  C1: Security Apparatus
# 0                South Sudan                    10.0
# 8                Afghanistan                    10.0
# 2                      Yemen                     9.9
# 3                      Syria                     9.9
# 46               Philippines                     9.8
# 1                    Somalia                     9.7
# 7                       Chad                     9.5
# 26                      Mali                     9.3
# 24                     Libya                     9.3
# 4   Central African Republic                     9.1

# %%
C1_sec=C1_df['Country'].head(10)

# %%
C1_sec.to_dict()
# Out:
# {0: 'South Sudan',
#  8: 'Afghanistan',
#  2: 'Yemen',
#  3: 'Syria',
#  46: 'Philippines',
#  1: 'Somalia',
#  7: 'Chad',
#  26: 'Mali',
#  24: 'Libya',
#  4: 'Central African Republic'}
