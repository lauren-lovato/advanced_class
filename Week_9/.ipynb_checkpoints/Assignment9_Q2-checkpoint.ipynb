# %% [markdown]
# ## Week 9, Assignment 9 Question 2

# %% [markdown]
# ###  Earthquakes from the past week from USGS Earthquakes Hazard Program

# %%
import arcgis
from arcgis.features import SpatialDataFrame 
import pandas as pd

# %%
eqw_csv = pd.read_csv("all_week.CSV")
eqw_csv.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2018-11-07T05:23:58.840Z  38.822166 -122.808502   1.21  2.27      md  31.0
# 1  2018-11-07T05:22:25.080Z  38.822834 -122.793999   2.78  0.98      md  14.0
# 2  2018-11-07T05:18:57.900Z  34.037667 -117.255833  15.05  1.38      ml  49.0
# 3  2018-11-07T05:08:38.450Z  33.316167 -116.339667  10.43  1.17      ml  53.0
# 4  2018-11-07T05:07:53.340Z  33.319500 -116.330500   9.18  0.98      ml  42.0
#
#     gap      dmin   rms    ...                      updated  \
# 0  47.0  0.001736  0.04    ...     2018-11-07T05:25:38.060Z
# 1  58.0  0.012570  0.02    ...     2018-11-07T05:24:03.045Z
# 2  46.0  0.074810  0.20    ...     2018-11-07T05:22:39.839Z
# 3  62.0  0.080630  0.25    ...     2018-11-07T05:12:19.134Z
# 4  71.0  0.088800  0.26    ...     2018-11-07T05:11:33.185Z
#
#                             place        type horizontalError depthError  \
# ...

# %%
eqw2_csv = pd.read_csv("all_week_aug_13_20.CSV")
eqw2_csv.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2018-08-21T02:23:41.411Z  63.099600 -144.310000   4.20  1.60      ml   NaN
# 1  2018-08-21T02:18:28.720Z  33.503833 -116.794000   2.91  0.36      ml  14.0
# 2  2018-08-21T02:13:08.870Z  33.502167 -116.793833   2.72  0.70      ml  22.0
# 3  2018-08-21T02:12:01.910Z  33.499000 -116.784000   2.77  0.50      ml  18.0
# 4  2018-08-21T02:06:18.720Z  33.252333 -116.409667   3.83  0.75      ml  12.0
#
#     gap     dmin   rms    ...                      updated  \
# 0   NaN      NaN  0.48    ...     2018-08-21T02:26:33.886Z
# 1  74.0  0.01003  0.09    ...     2018-08-21T02:21:57.452Z
# 2  67.0  0.01154  0.14    ...     2018-08-21T02:16:53.037Z
# 3  58.0  0.01909  0.12    ...     2018-08-21T02:15:42.724Z
# 4  80.0  0.01702  0.22    ...     2018-08-21T02:09:45.924Z
#
#                           place        type horizontalError depthError  \
# ...

# %%
df1 = pd.DataFrame(eqw_csv)
df2 = pd.DataFrame(eqw2_csv)

# %%
comb_df = df1.append(ignore_index=True, other=df2)

# %%
locations = comb_df.iloc[:,1:3].values.tolist()

# %%
sdf = SpatialDataFrame(comb_df,geometry=[arcgis.geometry.Geometry({'x':r[1], 'y':r[0], 
                    'spatialReference':{'wkid':4326}}) for r in locations])

# %%
sdf.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2018-11-07T05:23:58.840Z  38.822166 -122.808502   1.21  2.27      md  31.0
# 1  2018-11-07T05:22:25.080Z  38.822834 -122.793999   2.78  0.98      md  14.0
# 2  2018-11-07T05:18:57.900Z  34.037667 -117.255833  15.05  1.38      ml  49.0
# 3  2018-11-07T05:08:38.450Z  33.316167 -116.339667  10.43  1.17      ml  53.0
# 4  2018-11-07T05:07:53.340Z  33.319500 -116.330500   9.18  0.98      ml  42.0
#
#     gap      dmin   rms                        ...                          \
# 0  47.0  0.001736  0.04                        ...
# 1  58.0  0.012570  0.02                        ...
# 2  46.0  0.074810  0.20                        ...
# 3  62.0  0.080630  0.25                        ...
# 4  71.0  0.088800  0.26                        ...
#
#                             place        type horizontalError depthError  \
# 0       7km NW of The Geysers, CA  earthquake            0.16       0.27
# ...

# %%
sdf
# Out:
#                           time   latitude   longitude   depth   mag magType  \
# 0     2018-11-07T05:23:58.840Z  38.822166 -122.808502    1.21  2.27      md
# 1     2018-11-07T05:22:25.080Z  38.822834 -122.793999    2.78  0.98      md
# 2     2018-11-07T05:18:57.900Z  34.037667 -117.255833   15.05  1.38      ml
# 3     2018-11-07T05:08:38.450Z  33.316167 -116.339667   10.43  1.17      ml
# 4     2018-11-07T05:07:53.340Z  33.319500 -116.330500    9.18  0.98      ml
# 5     2018-11-07T05:07:10.430Z  33.313667 -116.332000   10.63  1.04      ml
# 6     2018-11-07T05:00:27.630Z  37.287998 -121.695168    7.49  1.29      md
# 7     2018-11-07T05:00:07.650Z  37.331833 -121.696167    7.42  1.22      md
# 8     2018-11-07T04:59:22.640Z  37.333668 -121.695999    7.55  1.23      md
# 9     2018-11-07T04:55:31.712Z  60.797000 -150.582800   40.80  1.60      ml
# 10    2018-11-07T04:55:03.920Z  33.478500 -116.792333    3.62  1.16      ml
# ...

# %%
sdf.reset_index(inplace=True, drop=True)
sdf.to_featureclass(out_location=r'C:\Users\Lauren\Documents\ArcGIS\Default.gdb', out_name='Earthquakes')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\ops.py in f(self, other)
#    1333             res = self._combine_const(other, func,
#    1334                                       errors='ignore',
# -> 1335                                       try_cast=False)
#    1336             return res.fillna(True).astype(bool)
#    1337
#
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\frame.py in _combine_const(self, other, func, errors, try_cast)
#    3986                                    errors=errors,
#    3987                                    try_cast=try_cast)
# -> 3988         return self._constructor(new_data)
#    3989
#    3990     def _compare_frame_evaluate(self, other, func, str_rep, try_cast=True):
#
# ...

# %% [markdown]
# #### gave me an error but created the feature class
